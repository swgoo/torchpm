# %%
import pandas as pd

df = pd.read_csv('regulation.txt', )

# %%
df
# Out:
#     0.5434804558753967  0.07436756044626236  0.9274773001670837  \
# 0             1.199211             0.729696           -0.201315
# 1            -0.670957             0.335363            2.022865
# 2             1.237489            -0.086661            0.633220
# 3             1.878202             0.187565           -0.466951
# 4             1.605704            -0.445210            0.591274
# ..                 ...                  ...                 ...
# 94            0.456542            -0.288213            1.000421
# 95           -0.792428             1.278361            0.554463
# 96            1.202828            -1.376670           -1.485283
# 97            0.752678            -0.353236           -0.577372
# 98           -0.007441             0.010218           -1.197006
#
#     0.5347446799278259  1.2311781644821167  0.4545213580131531  \
# 0             0.153081           -0.782409            0.481816
# 1             1.253884           -1.519141           -0.569556
# ...
